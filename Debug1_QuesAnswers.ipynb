# %% [markdown]
# **1. ANN Program**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate dummy dataset
data = pd.DataFrame({
    'Feature1': np.random.rand(100),
    'Feature2': np.random.rand(100),
    'Label': np.random.randint(0, 2, size=100)
})

# Split dataset
X = data[['Feature1', 'Feature2']]
y = data['Label']

# Scaling features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build ANN Model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(3,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=20, batch_size=16, validation_split=0.2)

# Evaluate the model
eval_loss, eval_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {eval_accuracy}")

# Predict
predictions = model.predict(X_test)
predicted_classes = (predictions > 0.5).astype(int)
print(predicted_classes[:10])

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate dummy dataset
data = pd.DataFrame({
    'Feature1': np.random.rand(100),
    'Feature2': np.random.rand(100),
    'Label': np.random.randint(0, 2, size=100)
})

# Split dataset
X = data[['Feature1', 'Feature2']]
y = data['Label']

# Scaling features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build ANN Model
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(2,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=20, batch_size=16, validation_split=0.2)

# Evaluate the model
eval_loss, eval_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {eval_accuracy}")

# Predict
predictions = model.predict(X_test)
predicted_classes = (predictions > 0.5).astype(int)
print(predicted_classes[:10])
# Out:
# 2026-09-14 17:45:59.139044: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/Max/opt/anaconda3/envs/DLenv1/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.5000 - loss: 0.7253 - val_accuracy: 0.5000 - val_loss: 0.6792
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5000 - loss: 0.7215 - val_accuracy: 0.5000 - val_loss: 0.6806
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5000 - loss: 0.7180 - val_accuracy: 0.5000 - val_loss: 0.6820
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5000 - loss: 0.7145 - val_accuracy: 0.5000 - val_loss: 0.6827
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.7126 - val_accuracy: 0.4375 - val_loss: 0.6841
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4844 - loss: 0.7092 - val_accuracy: 0.4375 - val_loss: 0.6847
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.7070 - val_accuracy: 0.4375 - val_loss: 0.6856
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4531 - loss: 0.7042 - val_accuracy: 0.4375 - val_loss: 0.6866
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4688 - loss: 0.7020 - val_accuracy: 0.5000 - val_loss: 0.6871
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4688 - loss: 0.6995 - val_accuracy: 0.5000 - val_loss: 0.6880
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 0.6976 - val_accuracy: 0.5000 - val_loss: 0.6891
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5312 - loss: 0.6963 - val_accuracy: 0.4375 - val_loss: 0.6904
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5312 - loss: 0.6947 - val_accuracy: 0.4375 - val_loss: 0.6917
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5312 - loss: 0.6931 - val_accuracy: 0.4375 - val_loss: 0.6929
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5312 - loss: 0.6920 - val_accuracy: 0.3750 - val_loss: 0.6938
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5469 - loss: 0.6905 - val_accuracy: 0.3125 - val_loss: 0.6949
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5625 - loss: 0.6897 - val_accuracy: 0.3125 - val_loss: 0.6961
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5625 - loss: 0.6886 - val_accuracy: 0.3125 - val_loss: 0.6975
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5938 - loss: 0.6877 - val_accuracy: 0.3125 - val_loss: 0.6991
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6094 - loss: 0.6866 - val_accuracy: 0.3125 - val_loss: 0.7010
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.6500 - loss: 0.6707
# Test Accuracy: 0.6499999761581421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# [[1]
#  [0]
#  [0]
#  [1]
#  [0]
#  [1]
#  [0]
#  [0]
#  [0]
#  [0]]

# %% [markdown]
# **bold text**## 2. CNN Program**

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 28, 28, 1)
y_train = np.random.randint(0, 10, size=(100,))

# Build a simple CNN
model = keras.sequentia([  # Error 1: Misspelled 'Sequential'
    layers.Conv2D(32, (3, 3), Activatin='relu', input_shape=(28, 28, 1)),  # Error 2: Misspelled 'activation'
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       6 X_train = np.random.rand(100, 28, 28, 1)
#       7 y_train = np.random.randint(0, 10, size=(100,))
#       8
#       9 # Build a simple CNN
# ---> 10 model = keras.Sequentia([  # Error 1: Misspelled 'Sequential'
#      11     layers.Conv2D(32, (3, 3), Activatin='relu', input_shape=(28, 28, 1)),  # Error 2: Misspelled 'activation'
#      12     layers.MaxPooling2D((2, 2)),
#      13     layers.Flatten(),
#
# AttributeError: module 'tensorflow.keras' has no attribute 'Sequentia'

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Create sample data
X_train = np.random.rand(100, 28, 28, 1)
y_train = np.random.randint(0, 10, size=(100,))

# Build a simple CNN
model = keras.Sequential([  # Error 1: Misspelled 'Sequential'
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),  # Error 2: Misspelled 'activation'
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# /Users/Max/opt/anaconda3/envs/DLenv1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.1300 - loss: 2.4244
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1500 - loss: 2.2780
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1800 - loss: 2.2603
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2500 - loss: 2.2297
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1900 - loss: 2.2121

# %% [markdown]
# ## **3.Library Installation Error (ANN)**

# %%
import Tensorflow as tf  # Error: Misspelled 'TensorFlow'
from tensorflow import keras
from tensorflow.Keras import layers

print("TensorFlow Version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import Tensorflow as tf  # Error: Misspelled 'TensorFlow'
#       2 from tensorflow import keras
#       3 from tensorflow.Keras import layers
#
# ModuleNotFoundError: No module named 'Tensorflow'

# %%
import tensorflow as tf  # Error: Misspelled 'TensorFlow'
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.16.1

# %% [markdown]
# ## **4.4. ModuleNotFoundError (Using Pretrained Model)**

# %%
from tensorflow.keras.applications import VGG1 # Error: VGG1 doesn't exist
model = VGG1(weights='imagenet')

# %%
from tensorflow.keras.applications import VGG16
model = VGG16(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 239s 0us/step

# %% [markdown]
# ## **5.TypeError (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 20)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(20,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# TypeError: batch_size should be integer, but passed as a float
model.fit(X_train, y_train, epochs=5, batch_size=32.0)  # Error: batch_size as float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 16
#      13 model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#      15 # TypeError: batch_size should be integer, but passed as a float
# ---> 16 model.fit(X_train, y_train, epochs=5, batch_size=32.0)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\tensorflow\python\framework\op_def_library.py:560, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     558     raise err
#     559   else:
# --> 560     raise TypeError(
#     561         f"Expected {dtypes.as_dtype(dtype).name} passed to parameter "
#     562         f"'{input_arg.name}' of op '{op_type_name}', got "
#     563         f"{repr(values)} of type '{type(values).__name__}' instead. "
#     564         f"Error: {err}")
#     565 except ValueError:
#     566   # What type does convert_to_tensor think it has?
#     567   try:
#
# TypeError: Expected int32 passed to parameter 'size' of op 'Slice', got [96.0] of type 'list' instead. Error: Expected int32, but got 96.0 of type 'float'.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 20)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(20,)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


model.fit(X_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.4700 - loss: 0.7101
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4700 - loss: 0.7045
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5000 - loss: 0.7013
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4700 - loss: 0.6985
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5200 - loss: 0.6968

# %% [markdown]
# ## **6.ValueError (Pretrained Model)**

# %%
from tensorflow.keras.applications import ResNet50
import numpy as np

# Create input data with wrong shape
input_data = np.random.rand(1, 224, 224)  # Error: Missing channel dimension

model = ResNet50(weights='imagenet')
prediction = model.predict(input_data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 23s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       5 input_data = np.random.rand(1, 224, 224)  # Error: Missing channel dimension
#       7 model = ResNet50(weights='imagenet')
# ----> 8 prediction = model.predict(input_data)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filehk0zjy6t.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\input_spec.py", line 235, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'resnet50' (type Functional).
#
#     Input 0 of layer "conv1_pad" is incompatible with the layer: expected ndim=4, found ndim=3. Full shape received: (None, 224, 224)
#
#     Call arguments received by layer 'resnet50' (type Functional):
#       • inputs=tf.Tensor(shape=(None, 224, 224), dtype=float32)
#       • training=False
#       • mask=None

# %%
from tensorflow.keras.applications import ResNet50
import numpy as np


input_data = np.random.rand(1, 224, 224,3)  

model = ResNet50(weights='imagenet')
prediction = model.predict(input_data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 29s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %% [markdown]
# ## **7.ImportError - Missing Library (ANN)**

# %%
import tensoflow as tf  # Error: Incorrect spelling, ImportError will occur
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    Layers.Dens(1, activation='sigmoid')
])

print("Model created successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       2 from tensorflow.keras import layers
#       3
#       4 model = tf.keras.Sequential([
#       5     layers.Dense(32, activation='relu', input_shape=(10,)),
# ----> 6     Layers.Dens(1, activation='sigmoid')
#       7 ])
#       8
#       9 print("Model created successfully.")
#
# NameError: name 'Layers' is not defined

# %%
import tensorflow as tf  # Error: Incorrect spelling, ImportError will occur
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

print("Model created successfully.")
# Out:
# Model created successfully.

# %% [markdown]
# ## **8. Attribute Error**

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Data with wrong shape (2D instead of 4D)
input_data = np.random.rand(1,28, 28)

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.Maxpooling2D((2, 2)),
    layers.flatten(),
    layers.Dense(10, activation='softmax')
])

# Error: Input data should have 4 dimensions (batch_size, height, width, channels)
prediction = model.predict(input_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 10
#       5 # Data with wrong shape (2D instead of 4D)
#       6 input_data = np.random.rand(1,28, 28)
#       8 model = keras.Sequential([
#       9     layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
# ---> 10     layers.Maxpooling2D((2, 2)),
#      11     layers.flatten(),
#      12     layers.Dense(10, activation='softmax')
#      13 ])
#      15 # Error: Input data should have 4 dimensions (batch_size, height, width, channels)
#      16 prediction = model.predict(input_data)
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Maxpooling2D'

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# Data with wrong shape (2D instead of 4D)
input_data = np.random.rand(1,28, 28)

model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(10, activation='softmax')
])

# Error: Input data should have 4 dimensions (batch_size, height, width, channels)
prediction = model.predict(input_data)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x174f1b9c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step

# %% [markdown]
# ## **9.TypeError - Incorrect Loss Function (ANN)**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# Error: Loss should be a string or a callable, not a number
model.compile(optimizer='adam', loss=0.5, metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 15
#      13 # Error: Loss should be a string or a callable, not a number
#      14 model.compile(optimizer='adam', loss=0.5, metrics=['accuracy'])
# ---> 15 model.fit(X_train, y_train, epochs=5)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filexruw74q6.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 1051, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\compile_utils.py", line 240, in __call__
#         self.build(y_pred)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\compile_utils.py", line 182, in build
#         self._losses = tf.nest.map_structure(
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\engine\compile_utils.py", line 353, in _get_loss_object
#         loss = losses_mod.get(loss)
#     File "C:\Users\Admin\anaconda3\envs\deepL\Lib\site-packages\keras\losses.py", line 2658, in get
#         raise ValueError(
#
#     ValueError: Could not interpret loss function identifier: 0.5

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# Error: Loss should be a string or a callable, not a number
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4800 - loss: 0.6969
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5100 - loss: 0.6941
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5100 - loss: 0.6932
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5000 - loss: 0.6924
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5500 - loss: 0.6917

# %% [markdown]
# ## **10.Invalid Function Error**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Generate random training data
X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# Error 1: Misspelled optimizer name ('adm' instead of 'adam')
# Error 2: Invalid loss function (should be a string or callable, not a number)
model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 16
#       9 model = tf.keras.Sequential([
#      10     layers.Dense(32, activation='relu', input_shape=(10,)),
#      11     layers.Dense(1, activation='sigmoid')
#      12 ])
#      14 # Error 1: Misspelled optimizer name ('adm' instead of 'adam')
#      15 # Error 2: Invalid loss function (should be a string or callable, not a number)
# ---> 16 model.compile(optimizer='adm', loss=0.5, metrics=['accuracy'])
#      18 model.fit(X_train, y_train, epochs=5)
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\deepL\Lib\site-packages\keras\saving\legacy\serialization.py:368, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     364 cls = object_registration.get_registered_object(
#     365     class_name, custom_objects, module_objects
#     366 )
#     367 if cls is None:
# --> 368     raise ValueError(
#     369         f"Unknown {printable_module_name}: '{class_name}'. "
#     370         "Please ensure you are using a `keras.utils.custom_object_scope` "
#     371         "and that this object is included in the scope. See "
#     372         "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     373         "#registering_the_custom_object for details."
#     374     )
#     376 cls_config = config["config"]
#     377 # Check if `cls_config` is a list. If it is a list, return the class and the
#     378 # associated class configs for recursively deserialization. This case will
#     379 # happen on the old version of sequential model (e.g. `keras_version` ==
#     380 # "2.0.6"), which is serialized in a different structure, for example
#     381 # "{'class_name': 'Sequential',
#     382 #   'config': [{'class_name': 'Embedding', 'config': ...}, {}, ...]}".
#
# ValueError: Unknown optimizer: 'adm'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Generate random training data
X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

model = tf.keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1, activation='sigmoid')
])

# Error 1: Misspelled optimizer name ('adm' instead of 'adam')
# Error 2: Invalid loss function (should be a string or callable, not a number)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5000 - loss: 0.6972
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5200 - loss: 0.6940
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5400 - loss: 0.6909
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5500 - loss: 0.6879
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5800 - loss: 0.6867
